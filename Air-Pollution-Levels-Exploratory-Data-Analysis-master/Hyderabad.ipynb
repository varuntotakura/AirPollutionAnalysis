# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib notebook

import seaborn as sns

# %%
plt.style.use("seaborn-colorblind")

# %%
data2 = pd.read_csv("C:/Users/VARUN/Desktop/AirPollution/Dataset/cpcb_dly_aq_andhra_pradesh-2002.csv")
data4 = pd.read_csv("C:/Users/VARUN/Desktop/AirPollution/Dataset/cpcb_dly_aq_andhra_pradesh-2004.csv")
data6 = pd.read_csv("C:/Users/VARUN/Desktop/AirPollution/Dataset/cpcb_dly_aq_andhra_pradesh-2006.csv")
data7 = pd.read_csv("C:/Users/VARUN/Desktop/AirPollution/Dataset/cpcb_dly_aq_andhra_pradesh-2007.csv")
data9 = pd.read_csv("C:/Users/VARUN/Desktop/AirPollution/Dataset/cpcb_dly_aq_andhra_pradesh-2009.csv")
data11 = pd.read_csv("C:/Users/VARUN/Desktop/AirPollution/Dataset/cpcb_dly_aq_andhra_pradesh-2011.csv")
data14 = pd.read_csv("C:/Users/VARUN/Desktop/AirPollution/Dataset/cpcb_dly_aq_telangana-2014.csv")

# %%
data4.head()
# Out:
#    Stn Code Sampling Date           State City/Town/Village/Area  \
# 0        95      1/2/2004  Andhra Pradesh              Hyderabad
# 1        95      1/5/2004  Andhra Pradesh              Hyderabad
# 2        95      1/9/2004  Andhra Pradesh              Hyderabad
# 3        95     1/12/2004  Andhra Pradesh              Hyderabad
# 4        95      16-01-04  Andhra Pradesh              Hyderabad
#
#                       Location of Monitoring Station  \
# 0  C.I.T.D., Balanagar, Plot no. A1 to A8, IDA, H...
# 1  C.I.T.D., Balanagar, Plot no. A1 to A8, IDA, H...
# 2  C.I.T.D., Balanagar, Plot no. A1 to A8, IDA, H...
# 3  C.I.T.D., Balanagar, Plot no. A1 to A8, IDA, H...
# 4  C.I.T.D., Balanagar, Plot no. A1 to A8, IDA, H...
#
#                                          Agency Type of Location   SO2    NO2  \
# 0  Andhra Pradesh State Pollution Control Board  Industrial Area  12.9   55.8
# 1  Andhra Pradesh State Pollution Control Board  Industrial Area  10.4   48.9
# ...

# %%
dates2 = []
for i,j in enumerate(data2['Sampling Date']):
    a = data2['Sampling Date'][i].split()[-1][1:][:2]
    b = data2['Sampling Date'][i].split()[-1][1:][4:]
    dates2.append(a+'-'+b)
dates4 = ['-'.join(i.split('/')[1:]) for i in data4['Sampling Date']]
dates6 = ['-'.join(i.split('/')[1:]) for i in data6['Sampling Date']]
dates7 = ['-'.join(i.split('/')[1:]) for i in data7['Sampling Date']]
dates9 = ['-'.join(i.split('/')[1:]) for i in data9['Sampling Date']]
dates11 = ['-'.join(i.split('/')[1:]) for i in data11['Sampling Date']]
dates14 = ['-'.join(i.split('-')[1:]) for i in data14['Sampling Date']]

# %%
data2['Sampling Date'] = dates2
data4['Sampling Date'] = dates4
data6['Sampling Date'] = dates6
data7['Sampling Date'] = dates7
data9['Sampling Date'] = dates9
data11['Sampling Date'] = dates11
data14['Sampling Date'] = dates14

# %%
for i in range(len(data2['City/Town/Village/Area'])):
    if data2['City/Town/Village/Area'][i] != 'Hyderabad':
        data2.drop(i, inplace = True)
for i in range(len(data4['City/Town/Village/Area'])):
    if data4['City/Town/Village/Area'][i] != 'Hyderabad':
        data4.drop(i, inplace = True)
for i in range(len(data6['City/Town/Village/Area'])):
    if data6['City/Town/Village/Area'][i] != 'Hyderabad':
        data6.drop(i, inplace = True)
for i in range(len(data7['City/Town/Village/Area'])):
    if data7['City/Town/Village/Area'][i] != 'Hyderabad':
        data7.drop(i, inplace = True)
for i in range(len(data9['City/Town/Village/Area'])):
    if data9['City/Town/Village/Area'][i] != 'Hyderabad':
        data9.drop(i, inplace = True)
for i in range(len(data11['City/Town/Village/Area'])):
    if data11['City/Town/Village/Area'][i] != 'Hyderabad':
        data11.drop(i, inplace = True)
for i in range(len(data14['City/Town/Village/Area'])):
    if data14['City/Town/Village/Area'][i] != 'Hyderabad':
        data14.drop(i, inplace = True)

# %%
data2.head()
data4.head()
data6.head()
data7.head()
data9.head()
data11.head()
data14.head()
# Out:
#    Stn Code Sampling Date      State City/Town/Village/Area  \
# 0        95         03-14  Telangana              Hyderabad
# 1        95         06-14  Telangana              Hyderabad
# 2        95         09-14  Telangana              Hyderabad
# 3        95         12-14  Telangana              Hyderabad
# 4        95         01-14  Telangana              Hyderabad
#
#                       Location of Monitoring Station  \
# 0  C.I.T.D., Balanagar, Plot no. A1 to A8, IDA, H...
# 1  C.I.T.D., Balanagar, Plot no. A1 to A8, IDA, H...
# 2  C.I.T.D., Balanagar, Plot no. A1 to A8, IDA, H...
# 3  C.I.T.D., Balanagar, Plot no. A1 to A8, IDA, H...
# 4  C.I.T.D., Balanagar, Plot no. A1 to A8, IDA, H...
#
#                                          Agency Type of Location  SO2   NO2  \
# 0  Andhra Pradesh State Pollution Control Board  Industrial Area  5.0  26.0
# 1  Andhra Pradesh State Pollution Control Board  Industrial Area  5.0  27.0
# ...

# %%
data = pd.concat([data4, data6, data7, data9, data11, data14], axis=0)
data = data.groupby("Sampling Date").mean()
try:
    data = data.drop("PM 2.5", axis=1)
    data = data.drop("SPM", axis=1)
    data = data.drop("Stn Code", axis=1)
except:
    pass
data.head()
# Out:
# C:\Users\VARUN\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#                      NO2   RSPM/PM10       SO2
# Sampling Date
#                28.120867   80.402003  4.568859
# 01-14          21.823529   95.981132  4.568627
# 02-14          22.724138   90.224138  5.275862
# 03-14          24.177966  105.008475  5.406780
# 04-14          21.650000  106.793651  5.400000

# %%
plt.figure(figsize=(9, 7))
plt.subplot(211)
plt.cla()
# plotter = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun','Jul', 'Aug', 'Sep',
#            'Oct', 'Nov', 'Dec']
x = np.arange(0,len(data["NO2"]),1)
ax = plt.gca()
ax.plot(x, data["NO2"])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xticks(x)
plt.xticks(rotation=45)
plt.subplots_adjust(bottom=0.2)
plt.legend([2014],loc=2)
plt.title("$\mathregular{NO_2}$ (Nitrogen Dioxide) levels in Hyderabad")
# ax.set_xticklabels(plotter)

plt.subplot(212)
plt.cla()
# plotter = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun','Jul', 'Aug', 'Sep',
#            'Oct', 'Nov', 'Dec']
x = np.arange(0,len(data["SO2"]),1)
ax = plt.gca()
ax.plot(x, data["SO2"])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xticks(x)
plt.xticks(rotation=45)
plt.title("$\mathregular{SO_2}$ (Sulphur Dioxide) levels in Hyderabad")
# ax.set_xticklabels(plotter)

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
import numpy as np 
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split

# %%
forecast_len=3

# %%
x=np.array(data.drop(['NO2'],1))
x=x[:-forecast_len]

y=np.array(data['NO2'])
y=y[:-forecast_len]

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

svr_rbf=SVR(kernel='rbf',C=1e3,gamma=0.1) 
svr_rbf.fit(x_train,y_train)
# Out:
# SVR(C=1000.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma=0.1,
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
svr_rbf_confidence=svr_rbf.score(x_test,y_test)
print(f"SVR Confidence: {round(svr_rbf_confidence*100,2)}%")
# Out:
# SVR Confidence: -142.99%

# %%
lr=LinearRegression(normalize=False)
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr_confidence=lr.score(x_test,y_test)
print(f"Linear Regression Confidence: {round(lr_confidence*100,2)}%")
# Out:
# Linear Regression Confidence: 7.94%

# %%
x_forecast = np.array(data.drop(['NO2'],1))[-forecast_len:]
print(x_forecast)
# Out:
# [[83.42857143  5.01714286]
#  [73.25806452  4.84835165]
#  [74.29487179  4.43974359]]

# %%
# Print linear regression model predictions for the next '30' days
lr_prediction = lr.predict(x_forecast)
print(lr_prediction)
# Print support vector regressor model predictions for the next '30' days
svm_prediction = svr_rbf.predict(x_forecast)
print(svm_prediction)
# Out:
# [25.52357742 25.21134876 25.98140672]
# [29.16223637 23.22357546 25.14805195]

# %%
plt.plot(lr_prediction)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

forecast_len = 3
x=np.array(data.drop(['NO2'],1))
x=x[:-forecast_len]

y=np.array(data['NO2'])
y=y[:-forecast_len]

sc = MinMaxScaler(feature_range=(0,1))
x = sc.fit_transform(x)

# %%
x_train = []
y_train = []

for i in range(3,60):
    x_train.append(x[i-3:i,0])
    y_train.append(x[i,0])
    
x=np.array(data.drop(['NO2'],1))
x=x[:-forecast_len]

y=np.array(data['NO2'])
y=y[:-forecast_len]

# x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

x_train,y_train = np.array(x_train),np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(128,return_sequences=True , input_shape = (x_train.shape[1],1)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.LSTM(512,return_sequences=True),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.LSTM(512,return_sequences=True),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.LSTM(512,return_sequences=True),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.LSTM(256,return_sequences=True),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.LSTM(128,return_sequences=True),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.LSTM(64),
    #tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(1)
])

model.compile(optimizer = 'adam',
             loss = 'mean_squared_error',
             metrics=['accuracy'])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_13 (LSTM)               (None, 3, 128)            66560
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 3, 128)            0
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 3, 512)            1312768
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 3, 512)            0
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 3, 512)            2099200
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 3, 512)            0
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 3, 512)            2099200
# ...

# %%
history = model.fit(x_train,y_train,epochs=50)#,batch_size=3)

predictions = model.predict(x_train)

#print(predictions)

plt.plot(range(len(x_train)), y_train, c='g')
plt.plot(range(len(x_train)), predictions, c='r')
plt.legend(['Green-Train', 'Red-Predictions'], loc='upper left')
plt.show()
# Out:
# Epoch 1/50
# 57/57 [==============================] - 15s 269ms/step - loss: 0.2522 - acc: 0.0000e+00
# Epoch 2/50
# 57/57 [==============================] - 2s 30ms/step - loss: 0.2360 - acc: 0.0000e+00
# Epoch 3/50
# 57/57 [==============================] - 2s 33ms/step - loss: 0.2078 - acc: 0.0000e+00
# Epoch 4/50
# 57/57 [==============================] - 2s 32ms/step - loss: 0.1675 - acc: 0.0000e+00
# Epoch 5/50
# 57/57 [==============================] - 1s 26ms/step - loss: 0.0988 - acc: 0.0000e+00
# Epoch 6/50
# 57/57 [==============================] - 1s 24ms/step - loss: 0.0585 - acc: 0.0175
# Epoch 7/50
# 57/57 [==============================] - 2s 31ms/step - loss: 0.0742 - acc: 0.0175
# Epoch 8/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.0500 - acc: 0.0000e+00
# Epoch 9/50
# 57/57 [==============================] - 2s 31ms/step - loss: 0.0560 - acc: 0.0000e+00
# Epoch 10/50
# ...

# %%
print(len(x_train),len(x_test),len(y_train),len(y_test))
#data = data.drop('RSPM/PM10', axis=1)
result= []
# Out:
# 57 14 57 14

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, LogisticRegression

x=np.array(data.drop(['NO2'],1))
y=np.array(data['NO2'])

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# Regression plot
def plot(x, y , predicted):
    plt.scatter(x, y, color='black')
    plt.plot(x, predicted,'-r')
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.show()

# Fit regression model
model = LinearRegression()
#model = LogisticRegression()

model.fit(x_train, y_train)
# predicted = model.predict(x_train)
# plot(x_train, y_train, predicted)

model.fit(x_train, y_train)
predicted = model.predict(x_test)

lr_confidence=model.score(x_test,y_test)

print("Linear Regression Confidence:", lr_confidence*100)
# Out:
# Linear Regression Confidence: 0.7971764697271788

# %%
plt.plot(predicted, c='g')
plt.plot(x_test, c='r')
plt.legend(['Green-Predictions', 'Red-Test'], loc='lower right')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
#setting up date parameter
import warnings
import itertools
import dateutil
# import statsmodels.api as sm
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

# %%
#exctracting knowledge about data

#spliting dataframes into test and train
n = data.shape[0]
train_size = 0.65

# features_dataframe = df.sort_values('date')
train = data.iloc[:int(n * train_size)]
test = data.iloc[int(n * train_size):]

# %%
#plotting the yearly variations of AQI

train.SO2.plot(title= 'YEARLY VARIATIONS')
test.SO2.plot(title= 'YEARLY VARIATIONS')
plt.show()

# %%
dd= np.asarray(train.SO2)
y_hat = test.copy()
y_hat['naive'] = dd[len(dd)-1]
plt.figure()
plt.plot(train.index, train['SO2'], label='Train')
plt.plot(test.index,test['SO2'], label='Test')
#plt.plot(y_hat.index,y_hat['naive'], label='Naive Forecast')
plt.legend(loc='best')
plt.title("Naive Forecast",fontsize=20)

plt.legend(["actual ","predicted"])
plt.xlabel("YEAR")
plt.ylabel("SO2")
plt.tick_params(labelsize=20)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
